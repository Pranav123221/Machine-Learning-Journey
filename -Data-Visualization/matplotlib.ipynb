# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0 , 5 , 11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)

# %%
plt.title("Hello")
# Out:
# Text(0.5, 1.0, 'Hello')

# %%
plt.xlabel("x-axis")
# Out:
# Text(0.5, 0, 'x-axis')

# %%
plt.subplot(2,2,1)
plt.plot(x==3 , y==4)

# %%
plt.subplot(2,2,4)
plt.plot(x , y)

# %%
## object oreinted way

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1 , 0.1 , 1 , 1])
axes1.plot(x , y)
axes2 = fig.add_axes([0.1 , 0.4 , 0.8 , 0.8])
axes2.plot(x , y)

# %%
## types of plot

# %%
plt.scatter(x , y)

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample
data = sample(range(1,1000) , 100)
plt.hist(data)
# Out:
# (array([ 7.,  8., 15.,  5.,  9., 11., 10., 12., 11., 12.]),
#  array([ 15. , 112.7, 210.4, 308.1, 405.8, 503.5, 601.2, 698.9, 796.6,
#         894.3, 992. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c4d9971310>,
#   <matplotlib.lines.Line2D at 0x1c4d9971450>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c4d9971590>,
#   <matplotlib.lines.Line2D at 0x1c4d99716d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c4d99711d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c4d9971810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c4d9971950>],
#  'means': []}

# %%
## saving

# %%
fig = plt.figure()
ax = fig.add_axes([0.3 , 0.3 , 0.8 , 0.8])
ax.plot(x , y)

# %%
plt.savefig("plotting.png")

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread("1781242086222.jpg")
img
# Out:
# array([[[165, 127,  90],
#         [167, 129,  93],
#         [167, 131,  95],
#         ...,
#         [216, 189, 168],
#         [215, 188, 167],
#         [214, 187, 166]],
#
#        [[165, 127,  90],
#         [167, 129,  93],
#         [167, 131,  95],
#         ...,
#         [216, 189, 168],
#         [215, 188, 167],
#         [214, 187, 166]],
#
#        [[166, 128,  91],
#         [167, 129,  92],
#         [168, 132,  96],
#         ...,
#         [216, 189, 168],
#         [215, 188, 167],
#         [214, 187, 166]],
#
#        ...,
#
#        [[122,  91,  45],
#         [122,  91,  45],
#         [122,  91,  45],
#         ...,
#         [253, 232, 213],
#         [252, 231, 212],
#         [252, 231, 212]],
#
#        [[122,  91,  45],
#         [122,  91,  45],
#         [122,  91,  45],
#         ...,
#         [253, 232, 213],
#         [252, 231, 212],
#         [252, 231, 212]],
#
#        [[123,  92,  46],
#         [123,  92,  46],
#         [123,  92,  46],
#         ...,
#         [253, 232, 213],
#         [252, 231, 212],
#         [252, 231, 212]]], shape=(2772, 2772, 3), dtype=uint8)

# %%
## show img

# %%
plt.imshow(img)
